# %%
import spacy

# %%
nlp = spacy.load('en_core_web_sm')

# %%
doc1 = nlp('''The son of a salesman who later operated an electrochemical factory, instein was born in the German 
Empire, but moved to Switzerland in 1895 and renounced his German citizenship in 1896. Specializing in physics and 
mathematics, he received his academic teaching diploma from the Swiss Federal Polytechnic School (German: 
eidgenössische polytechnische Schule) in Zürich in 1900. The following year, he acquired Swiss citizenship, which 
he kept for his entire life. After initially struggling to find work, from 1902 to 1909 he was employed as a patent examiner 
at the Swiss Patent Office in Bern.''')

# %%
for token in doc1:
    print(token.text)
# Out:
# The
# son
# of
# a
# salesman
# who
# later
# operated
# an
# electrochemical
# factory
# ,
# instein
# was
# born
# in
# the
# German
#
#
# Empire
# ,
# but
# moved
# to
# Switzerland
# in
# 1895
# and
# renounced
# his
# German
# citizenship
# in
# 1896
# .
# Specializing
# in
# physics
# and
#
#
# mathematics
# ,
# he
# received
# his
# academic
# teaching
# diploma
# from
# the
# Swiss
# Federal
# Polytechnic
# School
# (
# German
# :
#
#
# eidgenössische
# polytechnische
# Schule
# )
# in
# Zürich
# in
# 1900
# .
# The
# following
# year
# ,
# he
# acquired
# Swiss
# citizenship
# ,
# which
#
#
# he
# kept
# for
# his
# entire
# life
# .
# After
# initially
# struggling
# to
# find
# work
# ,
# from
# 1902
# to
# 1909
# he
# was
# employed
# as
# a
# patent
# examiner
#
#
# at
# the
# Swiss
# Patent
# Office
# in
# Bern
# .

# %%
for sent in doc1.sents:
    print(sent)
# Out:
# The son of a salesman who later operated an electrochemical factory, instein was born in the German
# Empire, but moved to Switzerland in 1895 and renounced his German citizenship in 1896.
# Specializing in physics and
# mathematics, he received his academic teaching diploma from the Swiss Federal Polytechnic School (German:
# eidgenössische polytechnische Schule) in Zürich in 1900.
# The following year, he acquired Swiss citizenship, which
# he kept for his entire life.
# After initially struggling to find work, from 1902 to 1909 he was employed as a patent examiner
# at the Swiss Patent Office in Bern.

# %%
for token in doc1:
    print("word is : " , token.text)
    print("Pos is : " , token.pos_ , "=", spacy.explain(token.pos_))
# Out:
# word is :  The
# Pos is :  DET = determiner
# word is :  son
# Pos is :  NOUN = noun
# word is :  of
# Pos is :  ADP = adposition
# word is :  a
# Pos is :  DET = determiner
# word is :  salesman
# Pos is :  NOUN = noun
# word is :  who
# Pos is :  PRON = pronoun
# word is :  later
# Pos is :  ADV = adverb
# word is :  operated
# Pos is :  VERB = verb
# word is :  an
# Pos is :  DET = determiner
# word is :  electrochemical
# Pos is :  ADJ = adjective
# word is :  factory
# Pos is :  NOUN = noun
# word is :  ,
# Pos is :  PUNCT = punctuation
# word is :  instein
# Pos is :  PROPN = proper noun
# word is :  was
# Pos is :  AUX = auxiliary
# word is :  born
# Pos is :  VERB = verb
# word is :  in
# Pos is :  ADP = adposition
# word is :  the
# Pos is :  DET = determiner
# word is :  German
# Pos is :  ADJ = adjective
# word is :
#
# Pos is :  SPACE = space
# word is :  Empire
# Pos is :  NOUN = noun
# word is :  ,
# Pos is :  PUNCT = punctuation
# word is :  but
# Pos is :  CCONJ = coordinating conjunction
# word is :  moved
# Pos is :  VERB = verb
# word is :  to
# Pos is :  ADP = adposition
# word is :  Switzerland
# Pos is :  PROPN = proper noun
# word is :  in
# Pos is :  ADP = adposition
# word is :  1895
# Pos is :  NUM = numeral
# word is :  and
# Pos is :  CCONJ = coordinating conjunction
# word is :  renounced
# Pos is :  VERB = verb
# word is :  his
# Pos is :  PRON = pronoun
# word is :  German
# Pos is :  ADJ = adjective
# word is :  citizenship
# Pos is :  NOUN = noun
# word is :  in
# Pos is :  ADP = adposition
# word is :  1896
# Pos is :  NUM = numeral
# word is :  .
# Pos is :  PUNCT = punctuation
# word is :  Specializing
# Pos is :  VERB = verb
# word is :  in
# Pos is :  ADP = adposition
# word is :  physics
# Pos is :  NOUN = noun
# word is :  and
# Pos is :  CCONJ = coordinating conjunction
# word is :
#
# Pos is :  SPACE = space
# word is :  mathematics
# Pos is :  NOUN = noun
# word is :  ,
# Pos is :  PUNCT = punctuation
# word is :  he
# Pos is :  PRON = pronoun
# word is :  received
# Pos is :  VERB = verb
# word is :  his
# Pos is :  PRON = pronoun
# word is :  academic
# Pos is :  ADJ = adjective
# word is :  teaching
# Pos is :  NOUN = noun
# word is :  diploma
# Pos is :  NOUN = noun
# word is :  from
# Pos is :  ADP = adposition
# word is :  the
# Pos is :  DET = determiner
# word is :  Swiss
# Pos is :  PROPN = proper noun
# word is :  Federal
# Pos is :  PROPN = proper noun
# word is :  Polytechnic
# Pos is :  PROPN = proper noun
# word is :  School
# Pos is :  PROPN = proper noun
# word is :  (
# Pos is :  PUNCT = punctuation
# word is :  German
# Pos is :  PROPN = proper noun
# word is :  :
# Pos is :  PUNCT = punctuation
# word is :
#
# Pos is :  SPACE = space
# word is :  eidgenössische
# Pos is :  NOUN = noun
# word is :  polytechnische
# Pos is :  PROPN = proper noun
# word is :  Schule
# Pos is :  PROPN = proper noun
# word is :  )
# Pos is :  PUNCT = punctuation
# word is :  in
# Pos is :  ADP = adposition
# word is :  Zürich
# Pos is :  PROPN = proper noun
# word is :  in
# Pos is :  ADP = adposition
# word is :  1900
# Pos is :  NUM = numeral
# word is :  .
# Pos is :  PUNCT = punctuation
# word is :  The
# Pos is :  DET = determiner
# word is :  following
# Pos is :  VERB = verb
# word is :  year
# Pos is :  NOUN = noun
# word is :  ,
# Pos is :  PUNCT = punctuation
# word is :  he
# Pos is :  PRON = pronoun
# word is :  acquired
# Pos is :  VERB = verb
# word is :  Swiss
# Pos is :  ADJ = adjective
# word is :  citizenship
# Pos is :  NOUN = noun
# word is :  ,
# Pos is :  PUNCT = punctuation
# word is :  which
# Pos is :  PRON = pronoun
# word is :
#
# Pos is :  SPACE = space
# word is :  he
# Pos is :  PRON = pronoun
# word is :  kept
# Pos is :  VERB = verb
# word is :  for
# Pos is :  ADP = adposition
# word is :  his
# Pos is :  PRON = pronoun
# word is :  entire
# Pos is :  ADJ = adjective
# word is :  life
# Pos is :  NOUN = noun
# word is :  .
# Pos is :  PUNCT = punctuation
# word is :  After
# Pos is :  ADP = adposition
# word is :  initially
# Pos is :  ADV = adverb
# word is :  struggling
# Pos is :  VERB = verb
# word is :  to
# Pos is :  PART = particle
# word is :  find
# Pos is :  VERB = verb
# word is :  work
# Pos is :  NOUN = noun
# word is :  ,
# Pos is :  PUNCT = punctuation
# word is :  from
# Pos is :  ADP = adposition
# word is :  1902
# Pos is :  NUM = numeral
# word is :  to
# Pos is :  ADP = adposition
# word is :  1909
# Pos is :  NUM = numeral
# word is :  he
# Pos is :  PRON = pronoun
# word is :  was
# Pos is :  AUX = auxiliary
# word is :  employed
# Pos is :  VERB = verb
# word is :  as
# Pos is :  ADP = adposition
# word is :  a
# Pos is :  DET = determiner
# word is :  patent
# Pos is :  NOUN = noun
# word is :  examiner
# Pos is :  NOUN = noun
# word is :
#
# Pos is :  SPACE = space
# word is :  at
# Pos is :  ADP = adposition
# word is :  the
# Pos is :  DET = determiner
# word is :  Swiss
# Pos is :  PROPN = proper noun
# word is :  Patent
# Pos is :  PROPN = proper noun
# word is :  Office
# Pos is :  PROPN = proper noun
# word is :  in
# Pos is :  ADP = adposition
# word is :  Bern
# Pos is :  PROPN = proper noun
# word is :  .
# Pos is :  PUNCT = punctuation

# %%
for token in doc1:
    print(token.text)
    print(token.dep_ , "=" , spacy.explain(token.dep_))
# Out:
# The
# det = determiner
# son
# nsubjpass = nominal subject (passive)
# of
# prep = prepositional modifier
# a
# det = determiner
# salesman
# pobj = object of preposition
# who
# nsubj = nominal subject
# later
# advmod = adverbial modifier
# operated
# relcl = relative clause modifier
# an
# det = determiner
# electrochemical
# amod = adjectival modifier
# factory
# dobj = direct object
# ,
# punct = punctuation
# instein
# nsubjpass = nominal subject (passive)
# was
# auxpass = auxiliary (passive)
# born
# ROOT = root
# in
# prep = prepositional modifier
# the
# det = determiner
# German
# amod = adjectival modifier
#
#
# dep = unclassified dependent
# Empire
# pobj = object of preposition
# ,
# punct = punctuation
# but
# cc = coordinating conjunction
# moved
# conj = conjunct
# to
# prep = prepositional modifier
# Switzerland
# pobj = object of preposition
# in
# prep = prepositional modifier
# 1895
# pobj = object of preposition
# and
# cc = coordinating conjunction
# renounced
# conj = conjunct
# his
# poss = possession modifier
# German
# amod = adjectival modifier
# citizenship
# dobj = direct object
# in
# prep = prepositional modifier
# 1896
# pobj = object of preposition
# .
# punct = punctuation
# Specializing
# advcl = adverbial clause modifier
# in
# prep = prepositional modifier
# physics
# pobj = object of preposition
# and
# cc = coordinating conjunction
#
#
# dep = unclassified dependent
# mathematics
# conj = conjunct
# ,
# punct = punctuation
# he
# nsubj = nominal subject
# received
# ROOT = root
# his
# poss = possession modifier
# academic
# amod = adjectival modifier
# teaching
# dobj = direct object
# diploma
# appos = appositional modifier
# from
# prep = prepositional modifier
# the
# det = determiner
# Swiss
# compound = compound
# Federal
# compound = compound
# Polytechnic
# compound = compound
# School
# pobj = object of preposition
# (
# punct = punctuation
# German
# appos = appositional modifier
# :
# punct = punctuation
#
#
# dep = unclassified dependent
# eidgenössische
# conj = conjunct
# polytechnische
# compound = compound
# Schule
# dobj = direct object
# )
# punct = punctuation
# in
# prep = prepositional modifier
# Zürich
# pobj = object of preposition
# in
# prep = prepositional modifier
# 1900
# pobj = object of preposition
# .
# punct = punctuation
# The
# det = determiner
# following
# amod = adjectival modifier
# year
# npadvmod = noun phrase as adverbial modifier
# ,
# punct = punctuation
# he
# nsubj = nominal subject
# acquired
# ROOT = root
# Swiss
# amod = adjectival modifier
# citizenship
# dobj = direct object
# ,
# punct = punctuation
# which
# dobj = direct object
#
#
# dep = unclassified dependent
# he
# nsubj = nominal subject
# kept
# relcl = relative clause modifier
# for
# prep = prepositional modifier
# his
# poss = possession modifier
# entire
# amod = adjectival modifier
# life
# pobj = object of preposition
# .
# punct = punctuation
# After
# prep = prepositional modifier
# initially
# advmod = adverbial modifier
# struggling
# pcomp = complement of preposition
# to
# aux = auxiliary
# find
# xcomp = open clausal complement
# work
# dobj = direct object
# ,
# punct = punctuation
# from
# prep = prepositional modifier
# 1902
# pobj = object of preposition
# to
# prep = prepositional modifier
# 1909
# pobj = object of preposition
# he
# nsubjpass = nominal subject (passive)
# was
# auxpass = auxiliary (passive)
# employed
# ROOT = root
# as
# prep = prepositional modifier
# a
# det = determiner
# patent
# compound = compound
# examiner
# pobj = object of preposition
#
#
# dep = unclassified dependent
# at
# prep = prepositional modifier
# the
# det = determiner
# Swiss
# compound = compound
# Patent
# compound = compound
# Office
# pobj = object of preposition
# in
# prep = prepositional modifier
# Bern
# pobj = object of preposition
# .
# punct = punctuation

# %%
for token in doc1:
    print(token.text)
    print(token.tag_ , "=" , spacy.explain(token.tag_))
# Out:
# The
# DT = determiner
# son
# NN = noun, singular or mass
# of
# IN = conjunction, subordinating or preposition
# a
# DT = determiner
# salesman
# NN = noun, singular or mass
# who
# WP = wh-pronoun, personal
# later
# RB = adverb
# operated
# VBD = verb, past tense
# an
# DT = determiner
# electrochemical
# JJ = adjective (English), other noun-modifier (Chinese)
# factory
# NN = noun, singular or mass
# ,
# , = punctuation mark, comma
# instein
# NNP = noun, proper singular
# was
# VBD = verb, past tense
# born
# VBN = verb, past participle
# in
# IN = conjunction, subordinating or preposition
# the
# DT = determiner
# German
# JJ = adjective (English), other noun-modifier (Chinese)
#
#
# _SP = whitespace
# Empire
# NN = noun, singular or mass
# ,
# , = punctuation mark, comma
# but
# CC = conjunction, coordinating
# moved
# VBD = verb, past tense
# to
# IN = conjunction, subordinating or preposition
# Switzerland
# NNP = noun, proper singular
# in
# IN = conjunction, subordinating or preposition
# 1895
# CD = cardinal number
# and
# CC = conjunction, coordinating
# renounced
# VBD = verb, past tense
# his
# PRP$ = pronoun, possessive
# German
# JJ = adjective (English), other noun-modifier (Chinese)
# citizenship
# NN = noun, singular or mass
# in
# IN = conjunction, subordinating or preposition
# 1896
# CD = cardinal number
# .
# . = punctuation mark, sentence closer
# Specializing
# VBG = verb, gerund or present participle
# in
# IN = conjunction, subordinating or preposition
# physics
# NN = noun, singular or mass
# and
# CC = conjunction, coordinating
#
#
# _SP = whitespace
# mathematics
# NNS = noun, plural
# ,
# , = punctuation mark, comma
# he
# PRP = pronoun, personal
# received
# VBD = verb, past tense
# his
# PRP$ = pronoun, possessive
# academic
# JJ = adjective (English), other noun-modifier (Chinese)
# teaching
# NN = noun, singular or mass
# diploma
# NN = noun, singular or mass
# from
# IN = conjunction, subordinating or preposition
# the
# DT = determiner
# Swiss
# NNP = noun, proper singular
# Federal
# NNP = noun, proper singular
# Polytechnic
# NNP = noun, proper singular
# School
# NNP = noun, proper singular
# (
# -LRB- = left round bracket
# German
# NNP = noun, proper singular
# :
# : = punctuation mark, colon or ellipsis
#
#
# _SP = whitespace
# eidgenössische
# NN = noun, singular or mass
# polytechnische
# NNP = noun, proper singular
# Schule
# NNP = noun, proper singular
# )
# -RRB- = right round bracket
# in
# IN = conjunction, subordinating or preposition
# Zürich
# NNP = noun, proper singular
# in
# IN = conjunction, subordinating or preposition
# 1900
# CD = cardinal number
# .
# . = punctuation mark, sentence closer
# The
# DT = determiner
# following
# VBG = verb, gerund or present participle
# year
# NN = noun, singular or mass
# ,
# , = punctuation mark, comma
# he
# PRP = pronoun, personal
# acquired
# VBD = verb, past tense
# Swiss
# JJ = adjective (English), other noun-modifier (Chinese)
# citizenship
# NN = noun, singular or mass
# ,
# , = punctuation mark, comma
# which
# WDT = wh-determiner
#
#
# _SP = whitespace
# he
# PRP = pronoun, personal
# kept
# VBD = verb, past tense
# for
# IN = conjunction, subordinating or preposition
# his
# PRP$ = pronoun, possessive
# entire
# JJ = adjective (English), other noun-modifier (Chinese)
# life
# NN = noun, singular or mass
# .
# . = punctuation mark, sentence closer
# After
# IN = conjunction, subordinating or preposition
# initially
# RB = adverb
# struggling
# VBG = verb, gerund or present participle
# to
# TO = infinitival "to"
# find
# VB = verb, base form
# work
# NN = noun, singular or mass
# ,
# , = punctuation mark, comma
# from
# IN = conjunction, subordinating or preposition
# 1902
# CD = cardinal number
# to
# IN = conjunction, subordinating or preposition
# 1909
# CD = cardinal number
# he
# PRP = pronoun, personal
# was
# VBD = verb, past tense
# employed
# VBN = verb, past participle
# as
# IN = conjunction, subordinating or preposition
# a
# DT = determiner
# patent
# NN = noun, singular or mass
# examiner
# NN = noun, singular or mass
#
#
# _SP = whitespace
# at
# IN = conjunction, subordinating or preposition
# the
# DT = determiner
# Swiss
# NNP = noun, proper singular
# Patent
# NNP = noun, proper singular
# Office
# NNP = noun, proper singular
# in
# IN = conjunction, subordinating or preposition
# Bern
# NNP = noun, proper singular
# .
# . = punctuation mark, sentence closer
